# %%
# %load_ext autoreload
# %autoreload 2
from __future__ import print_function
import os, cPickle
from collections import defaultdict, OrderedDict

import numpy as np
import keras.backend as K

import kde
import simplebinmi

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
sns.set_style('darkgrid')

import utils

# load data network was trained on
trn, tst = utils.get_IB_data('2017_12_21_16_51_3_275766')
# trn, tst = utils.get_mnist()

# calc MI for train and test. Save_activations must have been run with cfg['FULL_MI'] = True
FULL_MI = True

# Which measure to plot
infoplane_measure = 'upper'
# infoplane_measure = 'bin'

DO_SAVE        = True    # Whether to save plots or just show them
DO_LOWER       = (infoplane_measure == 'lower')   # Whether to compute lower bounds also
DO_BINNED      = (infoplane_measure == 'bin')     # Whether to compute MI estimates based on binning

MAX_EPOCHS = 10000      # Max number of epoch for which to compute mutual information measure
NUM_LABELS = 2
# MAX_EPOCHS = 1000
COLORBAR_MAX_EPOCHS = 10000

# Directories from which to load saved layer activity
# ARCH = '1024-20-20-20'
ARCH = '10-7-5-4-3'
#ARCH = '20-20-20-20-20-20'
#ARCH = '32-28-24-20-16-12'
#ARCH = '32-28-24-20-16-12-8-8'
DIR_TEMPLATE = '%%s_%s'%ARCH

# Functions to return upper and lower bounds on entropy of layer activity
noise_variance = 1e-3                    # Added Gaussian noise variance
binsize = 0.07                           # size of bins for binning method
Klayer_activity = K.placeholder(ndim=2)  # Keras placeholder 
entropy_func_upper = K.function([Klayer_activity,], [kde.entropy_estimator_kl(Klayer_activity, noise_variance),])
entropy_func_lower = K.function([Klayer_activity,], [kde.entropy_estimator_bd(Klayer_activity, noise_variance),])

# nats to bits conversion factor
nats2bits = 1.0/np.log(2) 

# Save indexes of tests data for each of the output classes
saved_labelixs = {}

y = tst.y
Y = tst.Y
if FULL_MI:
    full = utils.construct_full_dataset(trn,tst)
    y = full.y
    Y = full.Y

for i in range(NUM_LABELS):
    saved_labelixs[i] = y == i

labelprobs = np.mean(Y, axis=0)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
PLOT_LAYERS    = None     # Which layers to plot.  If None, all saved layers are plotted 

# Data structure used to store results
measures = OrderedDict()
measures['tanh'] = {}
measures['relu'] = {}
# measures['softsign'] = {}
# measures['softplus'] = {}

# %% [markdown]
# Compute MI measures
# -----

# %%
for activation in measures.keys():
    cur_dir = 'rawdata/' + DIR_TEMPLATE % activation
    if not os.path.exists(cur_dir):
        print("Directory %s not found" % cur_dir)
        continue
        
    # Load files saved during each epoch, and compute MI measures of the activity in that epoch
    print('*** Doing %s ***' % cur_dir)
    for epochfile in sorted(os.listdir(cur_dir)):
        if not epochfile.startswith('epoch'):
            continue
            
        fname = cur_dir + "/" + epochfile
        with open(fname, 'rb') as f:
            d = cPickle.load(f)

        epoch = d['epoch']
        if epoch in measures[activation]: # Skip this epoch if its already been processed
            continue                      # this is a trick to allow us to rerun this cell multiple times)
            
        if epoch > MAX_EPOCHS:
            continue

        print("Doing", fname)
        
        num_layers = len(d['data']['activity_tst'])

        if PLOT_LAYERS is None:
            PLOT_LAYERS = []
            for lndx in range(num_layers):
                #if d['data']['activity_tst'][lndx].shape[1] < 200 and lndx != num_layers - 1:
                PLOT_LAYERS.append(lndx)
                
        cepochdata = defaultdict(list)
        for lndx in range(num_layers):
            activity = d['data']['activity_tst'][lndx]

            # Compute marginal entropies
            h_upper = entropy_func_upper([activity,])[0]
            if DO_LOWER:
                h_lower = entropy_func_lower([activity,])[0]
                
            # Layer activity given input. This is simply the entropy of the Gaussian noise
            hM_given_X = kde.kde_condentropy(activity, noise_variance)

            # Compute conditional entropies of layer activity given output
            hM_given_Y_upper=0.
            for i in range(NUM_LABELS):
                hcond_upper = entropy_func_upper([activity[saved_labelixs[i],:],])[0]
                hM_given_Y_upper += labelprobs[i] * hcond_upper
                
            if DO_LOWER:
                hM_given_Y_lower=0.
                for i in range(NUM_LABELS):
                    hcond_lower = entropy_func_lower([activity[saved_labelixs[i],:],])[0]
                    hM_given_Y_lower += labelprobs[i] * hcond_lower
                
            cepochdata['MI_XM_upper'].append( nats2bits * (h_upper - hM_given_X) )
            cepochdata['MI_YM_upper'].append( nats2bits * (h_upper - hM_given_Y_upper) )
            cepochdata['H_M_upper'  ].append( nats2bits * h_upper )

            pstr = 'upper: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_upper'][-1], cepochdata['MI_YM_upper'][-1])
            if DO_LOWER:  # Compute lower bounds
                cepochdata['MI_XM_lower'].append( nats2bits * (h_lower - hM_given_X) )
                cepochdata['MI_YM_lower'].append( nats2bits * (h_lower - hM_given_Y_lower) )
                cepochdata['H_M_lower'  ].append( nats2bits * h_lower )
                pstr += ' | lower: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_lower'][-1], cepochdata['MI_YM_lower'][-1])

            if DO_BINNED: # Compute binned estimates
                binxm, binym = simplebinmi.bin_calc_information2(saved_labelixs, activity, binsize)
                cepochdata['MI_XM_bin'].append( nats2bits * binxm )
                cepochdata['MI_YM_bin'].append( nats2bits * binym )
                pstr += ' | bin: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_bin'][-1], cepochdata['MI_YM_bin'][-1])
                        
            print('- Layer %d %s' % (lndx, pstr) )

        measures[activation][epoch] = cepochdata
# Out:
# *** Doing rawdata/tanh_10-7-5-4-3 ***
# Doing rawdata/tanh_10-7-5-4-3/epoch00000000
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999 | bin: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.989, MI(Y;M)=0.996 | bin: MI(X;M)=11.996, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.768, MI(Y;M)=0.905 | bin: MI(X;M)=11.893, MI(Y;M)=0.957
# - Layer 3 upper: MI(X;M)=11.080, MI(Y;M)=0.657 | bin: MI(X;M)=11.424, MI(Y;M)=0.759
# - Layer 4 upper: MI(X;M)=8.791, MI(Y;M)=0.205 | bin: MI(X;M)=9.383, MI(Y;M)=0.247
# - Layer 5 upper: MI(X;M)=1.802, MI(Y;M)=0.006 | bin: MI(X;M)=2.353, MI(Y;M)=0.010
# Doing rawdata/tanh_10-7-5-4-3/epoch00000001
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999 | bin: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.989, MI(Y;M)=0.996 | bin: MI(X;M)=11.996, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.771, MI(Y;M)=0.906 | bin: MI(X;M)=11.895, MI(Y;M)=0.958
# - Layer 3 upper: MI(X;M)=11.098, MI(Y;M)=0.665 | bin: MI(X;M)=11.483, MI(Y;M)=0.792
# - Layer 4 upper: MI(X;M)=8.814, MI(Y;M)=0.209 | bin: MI(X;M)=9.393, MI(Y;M)=0.256
# - Layer 5 upper: MI(X;M)=1.691, MI(Y;M)=0.011 | bin: MI(X;M)=2.260, MI(Y;M)=0.013
# Doing rawdata/tanh_10-7-5-4-3/epoch00000002
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999 | bin: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.989, MI(Y;M)=0.996 | bin: MI(X;M)=11.994, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.775, MI(Y;M)=0.908 | bin: MI(X;M)=11.883, MI(Y;M)=0.954
# - Layer 3 upper: MI(X;M)=11.098, MI(Y;M)=0.667 | bin: MI(X;M)=11.480, MI(Y;M)=0.776
# - Layer 4 upper: MI(X;M)=8.818, MI(Y;M)=0.219 | bin: MI(X;M)=9.383, MI(Y;M)=0.266
# - Layer 5 upper: MI(X;M)=1.583, MI(Y;M)=0.018 | bin: MI(X;M)=2.181, MI(Y;M)=0.017
# Doing rawdata/tanh_10-7-5-4-3/epoch00000003
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999 | bin: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.989, MI(Y;M)=0.996 | bin: MI(X;M)=11.994, MI(Y;M)=0.997
# - Layer 2 upper: MI(X;M)=11.780, MI(Y;M)=0.909 | bin: MI(X;M)=11.898, MI(Y;M)=0.955
# - Layer 3 upper: MI(X;M)=11.096, MI(Y;M)=0.666 | bin: MI(X;M)=11.465, MI(Y;M)=0.765
# - Layer 4 upper: MI(X;M)=8.833, MI(Y;M)=0.231 | bin: MI(X;M)=9.389, MI(Y;M)=0.266
# - Layer 5 upper: MI(X;M)=1.512, MI(Y;M)=0.028 | bin: MI(X;M)=2.118, MI(Y;M)=0.030
# Doing rawdata/tanh_10-7-5-4-3/epoch00000004
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999 | bin: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.990, MI(Y;M)=0.996 | bin: MI(X;M)=11.998, MI(Y;M)=0.998
# - Layer 2 upper: MI(X;M)=11.783, MI(Y;M)=0.910 | bin: MI(X;M)=11.894, MI(Y;M)=0.952
# - Layer 3 upper: MI(X;M)=11.087, MI(Y;M)=0.663 | bin: MI(X;M)=11.448, MI(Y;M)=0.773
# - Layer 4 upper: MI(X;M)=8.845, MI(Y;M)=0.241 | bin: MI(X;M)=9.385, MI(Y;M)=0.279
# - Layer 5 upper: MI(X;M)=1.471, MI(Y;M)=0.043 | bin: MI(X;M)=2.083, MI(Y;M)=0.044
# Doing rawdata/tanh_10-7-5-4-3/epoch00000005
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999 | bin: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.990, MI(Y;M)=0.996 | bin: MI(X;M)=11.996, MI(Y;M)=0.998
# - Layer 2 upper: MI(X;M)=11.786, MI(Y;M)=0.912 | bin: MI(X;M)=11.897, MI(Y;M)=0.955
# - Layer 3 upper: MI(X;M)=11.080, MI(Y;M)=0.664 | bin: MI(X;M)=11.442, MI(Y;M)=0.778
# - Layer 4 upper: MI(X;M)=8.874, MI(Y;M)=0.253 | bin: MI(X;M)=9.429, MI(Y;M)=0.292
# - Layer 5 upper: MI(X;M)=1.512, MI(Y;M)=0.059 | bin: MI(X;M)=2.138, MI(Y;M)=0.057
# Doing rawdata/tanh_10-7-5-4-3/epoch00000006
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999 | bin: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.991, MI(Y;M)=0.996 | bin: MI(X;M)=11.999, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.793, MI(Y;M)=0.916 | bin: MI(X;M)=11.886, MI(Y;M)=0.952
# - Layer 3 upper: MI(X;M)=11.087, MI(Y;M)=0.671 | bin: MI(X;M)=11.439, MI(Y;M)=0.777
# - Layer 4 upper: MI(X;M)=8.924, MI(Y;M)=0.266 | bin: MI(X;M)=9.487, MI(Y;M)=0.311
# - Layer 5 upper: MI(X;M)=1.563, MI(Y;M)=0.076 | bin: MI(X;M)=2.175, MI(Y;M)=0.076
# Doing rawdata/tanh_10-7-5-4-3/epoch00000007
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999 | bin: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.991, MI(Y;M)=0.997 | bin: MI(X;M)=11.997, MI(Y;M)=0.998
# - Layer 2 upper: MI(X;M)=11.793, MI(Y;M)=0.917 | bin: MI(X;M)=11.902, MI(Y;M)=0.961
# - Layer 3 upper: MI(X;M)=11.079, MI(Y;M)=0.677 | bin: MI(X;M)=11.444, MI(Y;M)=0.778
# - Layer 4 upper: MI(X;M)=8.968, MI(Y;M)=0.283 | bin: MI(X;M)=9.505, MI(Y;M)=0.327
# - Layer 5 upper: MI(X;M)=1.643, MI(Y;M)=0.094 | bin: MI(X;M)=2.227, MI(Y;M)=0.091
# Doing rawdata/tanh_10-7-5-4-3/epoch00000008
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999 | bin: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.992, MI(Y;M)=0.997 | bin: MI(X;M)=11.996, MI(Y;M)=0.998
# - Layer 2 upper: MI(X;M)=11.791, MI(Y;M)=0.918 | bin: MI(X;M)=11.901, MI(Y;M)=0.959
# - Layer 3 upper: MI(X;M)=11.069, MI(Y;M)=0.682 | bin: MI(X;M)=11.439, MI(Y;M)=0.792
# - Layer 4 upper: MI(X;M)=9.016, MI(Y;M)=0.302 | bin: MI(X;M)=9.561, MI(Y;M)=0.345
# - Layer 5 upper: MI(X;M)=1.750, MI(Y;M)=0.112 | bin: MI(X;M)=2.299, MI(Y;M)=0.111
# Doing rawdata/tanh_10-7-5-4-3/epoch00000009
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999 | bin: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.992, MI(Y;M)=0.997 | bin: MI(X;M)=11.998, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.790, MI(Y;M)=0.920 | bin: MI(X;M)=11.895, MI(Y;M)=0.953
# - Layer 3 upper: MI(X;M)=11.069, MI(Y;M)=0.690 | bin: MI(X;M)=11.433, MI(Y;M)=0.798
# - Layer 4 upper: MI(X;M)=9.081, MI(Y;M)=0.320 | bin: MI(X;M)=9.594, MI(Y;M)=0.358
# - Layer 5 upper: MI(X;M)=1.861, MI(Y;M)=0.129 | bin: MI(X;M)=2.415, MI(Y;M)=0.125
# Doing rawdata/tanh_10-7-5-4-3/epoch00000010
# - Layer 0 upper: MI(X;M)=12.000, MI(Y;M)=0.999 | bin: MI(X;M)=12.000, MI(Y;M)=0.999
# - Layer 1 upper: MI(X;M)=11.992, MI(Y;M)=0.997 | bin: MI(X;M)=11.998, MI(Y;M)=0.999
# - Layer 2 upper: MI(X;M)=11.786, MI(Y;M)=0.921 | bin: MI(X;M)=11.900, MI(Y;M)=0.963
# - Layer 3 upper: MI(X;M)=11.059, MI(Y;M)=0.695 | bin: MI(X;M)=11.400, MI(Y;M)=0.786
# - Layer 4 upper: MI(X;M)=9.136, MI(Y;M)=0.338 | bin: MI(X;M)=9.672, MI(Y;M)=0.381
# - Layer 5 upper: MI(X;M)=1.978, MI(Y;M)=0.147 | bin: MI(X;M)=2.518, MI(Y;M)=0.142
# *** Doing rawdata/relu_10-7-5-4-3 ***
# Doing rawdata/relu_10-7-5-4-3/epoch00000000
# - Layer 0 upper: MI(X;M)=11.969, MI(Y;M)=0.989 | bin: MI(X;M)=11.963, MI(Y;M)=0.987
# - Layer 1 upper: MI(X;M)=10.691, MI(Y;M)=0.638 | bin: MI(X;M)=10.645, MI(Y;M)=0.644
# - Layer 2 upper: MI(X;M)=6.817, MI(Y;M)=0.123 | bin: MI(X;M)=6.944, MI(Y;M)=0.143
# - Layer 3 upper: MI(X;M)=3.766, MI(Y;M)=0.014 | bin: MI(X;M)=3.928, MI(Y;M)=0.016
# - Layer 4 upper: MI(X;M)=0.717, MI(Y;M)=0.001 | bin: MI(X;M)=0.239, MI(Y;M)=0.000
# - Layer 5 upper: MI(X;M)=0.078, MI(Y;M)=0.000 | bin: MI(X;M)=0.733, MI(Y;M)=0.000
# Doing rawdata/relu_10-7-5-4-3/epoch00000001
# - Layer 0 upper: MI(X;M)=11.968, MI(Y;M)=0.988 | bin: MI(X;M)=11.964, MI(Y;M)=0.988
# - Layer 1 upper: MI(X;M)=10.778, MI(Y;M)=0.658 | bin: MI(X;M)=10.707, MI(Y;M)=0.666
# - Layer 2 upper: MI(X;M)=6.865, MI(Y;M)=0.128 | bin: MI(X;M)=6.971, MI(Y;M)=0.135
# - Layer 3 upper: MI(X;M)=3.820, MI(Y;M)=0.016 | bin: MI(X;M)=3.984, MI(Y;M)=0.016
# - Layer 4 upper: MI(X;M)=0.793, MI(Y;M)=0.001 | bin: MI(X;M)=0.307, MI(Y;M)=0.001
# - Layer 5 upper: MI(X;M)=0.088, MI(Y;M)=0.000 | bin: MI(X;M)=0.827, MI(Y;M)=0.001
# Doing rawdata/relu_10-7-5-4-3/epoch00000002
# - Layer 0 upper: MI(X;M)=11.967, MI(Y;M)=0.988 | bin: MI(X;M)=11.965, MI(Y;M)=0.989
# - Layer 1 upper: MI(X;M)=10.850, MI(Y;M)=0.673 | bin: MI(X;M)=10.798, MI(Y;M)=0.681
# - Layer 2 upper: MI(X;M)=6.909, MI(Y;M)=0.134 | bin: MI(X;M)=7.015, MI(Y;M)=0.137
# - Layer 3 upper: MI(X;M)=3.876, MI(Y;M)=0.018 | bin: MI(X;M)=4.041, MI(Y;M)=0.018
# - Layer 4 upper: MI(X;M)=0.900, MI(Y;M)=0.002 | bin: MI(X;M)=0.406, MI(Y;M)=0.001
# - Layer 5 upper: MI(X;M)=0.096, MI(Y;M)=0.000 | bin: MI(X;M)=0.888, MI(Y;M)=0.005
# Doing rawdata/relu_10-7-5-4-3/epoch00000003
# - Layer 0 upper: MI(X;M)=11.968, MI(Y;M)=0.989 | bin: MI(X;M)=11.967, MI(Y;M)=0.991
# - Layer 1 upper: MI(X;M)=10.945, MI(Y;M)=0.697 | bin: MI(X;M)=10.918, MI(Y;M)=0.712
# - Layer 2 upper: MI(X;M)=7.006, MI(Y;M)=0.142 | bin: MI(X;M)=7.114, MI(Y;M)=0.150
# - Layer 3 upper: MI(X;M)=3.984, MI(Y;M)=0.020 | bin: MI(X;M)=4.164, MI(Y;M)=0.024
# - Layer 4 upper: MI(X;M)=1.014, MI(Y;M)=0.004 | bin: MI(X;M)=0.526, MI(Y;M)=0.001
# - Layer 5 upper: MI(X;M)=0.115, MI(Y;M)=0.001 | bin: MI(X;M)=0.970, MI(Y;M)=0.005
# Doing rawdata/relu_10-7-5-4-3/epoch00000004
# - Layer 0 upper: MI(X;M)=11.969, MI(Y;M)=0.990 | bin: MI(X;M)=11.964, MI(Y;M)=0.991
# - Layer 1 upper: MI(X;M)=11.032, MI(Y;M)=0.722 | bin: MI(X;M)=10.998, MI(Y;M)=0.722
# - Layer 2 upper: MI(X;M)=7.120, MI(Y;M)=0.152 | bin: MI(X;M)=7.221, MI(Y;M)=0.163
# - Layer 3 upper: MI(X;M)=4.102, MI(Y;M)=0.024 | bin: MI(X;M)=4.299, MI(Y;M)=0.025
# - Layer 4 upper: MI(X;M)=1.130, MI(Y;M)=0.005 | bin: MI(X;M)=0.660, MI(Y;M)=0.003
# - Layer 5 upper: MI(X;M)=0.137, MI(Y;M)=0.001 | bin: MI(X;M)=0.996, MI(Y;M)=0.006
# Doing rawdata/relu_10-7-5-4-3/epoch00000005
# - Layer 0 upper: MI(X;M)=11.970, MI(Y;M)=0.991 | bin: MI(X;M)=11.965, MI(Y;M)=0.991
# - Layer 1 upper: MI(X;M)=11.116, MI(Y;M)=0.747 | bin: MI(X;M)=11.082, MI(Y;M)=0.739
# - Layer 2 upper: MI(X;M)=7.251, MI(Y;M)=0.161 | bin: MI(X;M)=7.353, MI(Y;M)=0.171
# - Layer 3 upper: MI(X;M)=4.215, MI(Y;M)=0.027 | bin: MI(X;M)=4.417, MI(Y;M)=0.029
# - Layer 4 upper: MI(X;M)=1.220, MI(Y;M)=0.008 | bin: MI(X;M)=0.761, MI(Y;M)=0.004
# - Layer 5 upper: MI(X;M)=0.160, MI(Y;M)=0.002 | bin: MI(X;M)=0.999, MI(Y;M)=0.009
# Doing rawdata/relu_10-7-5-4-3/epoch00000006
# - Layer 0 upper: MI(X;M)=11.970, MI(Y;M)=0.991 | bin: MI(X;M)=11.965, MI(Y;M)=0.990
# - Layer 1 upper: MI(X;M)=11.205, MI(Y;M)=0.773 | bin: MI(X;M)=11.195, MI(Y;M)=0.775
# - Layer 2 upper: MI(X;M)=7.383, MI(Y;M)=0.169 | bin: MI(X;M)=7.527, MI(Y;M)=0.194
# - Layer 3 upper: MI(X;M)=4.325, MI(Y;M)=0.032 | bin: MI(X;M)=4.508, MI(Y;M)=0.033
# - Layer 4 upper: MI(X;M)=1.307, MI(Y;M)=0.010 | bin: MI(X;M)=0.873, MI(Y;M)=0.007
# - Layer 5 upper: MI(X;M)=0.192, MI(Y;M)=0.003 | bin: MI(X;M)=0.998, MI(Y;M)=0.010
# Doing rawdata/relu_10-7-5-4-3/epoch00000007
# - Layer 0 upper: MI(X;M)=11.972, MI(Y;M)=0.992 | bin: MI(X;M)=11.970, MI(Y;M)=0.988
# - Layer 1 upper: MI(X;M)=11.301, MI(Y;M)=0.797 | bin: MI(X;M)=11.300, MI(Y;M)=0.802
# - Layer 2 upper: MI(X;M)=7.538, MI(Y;M)=0.186 | bin: MI(X;M)=7.663, MI(Y;M)=0.200
# - Layer 3 upper: MI(X;M)=4.460, MI(Y;M)=0.038 | bin: MI(X;M)=4.676, MI(Y;M)=0.037
# - Layer 4 upper: MI(X;M)=1.460, MI(Y;M)=0.014 | bin: MI(X;M)=1.064, MI(Y;M)=0.014
# - Layer 5 upper: MI(X;M)=0.239, MI(Y;M)=0.005 | bin: MI(X;M)=0.982, MI(Y;M)=0.009
# Doing rawdata/relu_10-7-5-4-3/epoch00000008
# - Layer 0 upper: MI(X;M)=11.974, MI(Y;M)=0.993 | bin: MI(X;M)=11.971, MI(Y;M)=0.992
# - Layer 1 upper: MI(X;M)=11.403, MI(Y;M)=0.822 | bin: MI(X;M)=11.403, MI(Y;M)=0.820
# - Layer 2 upper: MI(X;M)=7.660, MI(Y;M)=0.203 | bin: MI(X;M)=7.802, MI(Y;M)=0.220
# - Layer 3 upper: MI(X;M)=4.611, MI(Y;M)=0.044 | bin: MI(X;M)=4.817, MI(Y;M)=0.045
# - Layer 4 upper: MI(X;M)=1.615, MI(Y;M)=0.019 | bin: MI(X;M)=1.255, MI(Y;M)=0.020
# - Layer 5 upper: MI(X;M)=0.300, MI(Y;M)=0.008 | bin: MI(X;M)=0.942, MI(Y;M)=0.010
# Doing rawdata/relu_10-7-5-4-3/epoch00000009
# - Layer 0 upper: MI(X;M)=11.976, MI(Y;M)=0.993 | bin: MI(X;M)=11.975, MI(Y;M)=0.995
# - Layer 1 upper: MI(X;M)=11.476, MI(Y;M)=0.839 | bin: MI(X;M)=11.487, MI(Y;M)=0.847
# - Layer 2 upper: MI(X;M)=7.807, MI(Y;M)=0.216 | bin: MI(X;M)=7.954, MI(Y;M)=0.239
# - Layer 3 upper: MI(X;M)=4.779, MI(Y;M)=0.052 | bin: MI(X;M)=4.973, MI(Y;M)=0.050
# - Layer 4 upper: MI(X;M)=1.758, MI(Y;M)=0.024 | bin: MI(X;M)=1.411, MI(Y;M)=0.022
# - Layer 5 upper: MI(X;M)=0.367, MI(Y;M)=0.011 | bin: MI(X;M)=0.944, MI(Y;M)=0.012
# Doing rawdata/relu_10-7-5-4-3/epoch00000010
# - Layer 0 upper: MI(X;M)=11.977, MI(Y;M)=0.993 | bin: MI(X;M)=11.975, MI(Y;M)=0.993
# - Layer 1 upper: MI(X;M)=11.553, MI(Y;M)=0.856 | bin: MI(X;M)=11.572, MI(Y;M)=0.865
# - Layer 2 upper: MI(X;M)=7.941, MI(Y;M)=0.228 | bin: MI(X;M)=8.105, MI(Y;M)=0.252
# - Layer 3 upper: MI(X;M)=4.969, MI(Y;M)=0.061 | bin: MI(X;M)=5.149, MI(Y;M)=0.062
# - Layer 4 upper: MI(X;M)=1.909, MI(Y;M)=0.030 | bin: MI(X;M)=1.606, MI(Y;M)=0.026
# - Layer 5 upper: MI(X;M)=0.467, MI(Y;M)=0.017 | bin: MI(X;M)=0.953, MI(Y;M)=0.017

# %% [markdown]
# Plot Infoplane Visualization
# ----

# %%
max_epoch = max( (max(vals.keys()) if len(vals) else 0) for vals in measures.values())
sm = plt.cm.ScalarMappable(cmap='gnuplot', norm=plt.Normalize(vmin=0, vmax=COLORBAR_MAX_EPOCHS))
sm._A = []

fig=plt.figure(figsize=(10,5))
for actndx, (activation, vals) in enumerate(measures.items()):
    epochs = sorted(vals.keys())
    if not len(epochs):
        continue
    plt.subplot(1,2,actndx+1)    
    for epoch in epochs:
        c = sm.to_rgba(epoch)
        xmvals = np.array(vals[epoch]['MI_XM_'+infoplane_measure])[PLOT_LAYERS]
        ymvals = np.array(vals[epoch]['MI_YM_'+infoplane_measure])[PLOT_LAYERS]

        plt.plot(xmvals, ymvals, c=c, alpha=0.1, zorder=1)
        plt.scatter(xmvals, ymvals, s=20, facecolors=[c for _ in PLOT_LAYERS], edgecolor='none', zorder=2)

    plt.ylim([0, 1])
    plt.xlim([0, 12])
#     plt.ylim([0, 3.5])
#     plt.xlim([0, 14])
    plt.xlabel('I(X;M)')
    plt.ylabel('I(Y;M)')
    plt.title(activation)
    
cbaxes = fig.add_axes([1.0, 0.125, 0.03, 0.8]) 
plt.colorbar(sm, label='Epoch', cax=cbaxes)
plt.tight_layout()

if DO_SAVE:
    plt.savefig('plots/' + DIR_TEMPLATE % ('infoplane_'+ARCH),bbox_inches='tight')

# %% [markdown]
# Plot SNR curves
# ----

# %%
plt.figure(figsize=(12,5))

gs = gridspec.GridSpec(len(measures), len(PLOT_LAYERS))
for activation in measures.keys():
    cur_dir = 'rawdata/' + DIR_TEMPLATE % activation
    if not os.path.exists(cur_dir):
        continue
        
    epochs = []
    means = []
    stds = []
    wnorms = []
    for epochfile in sorted(os.listdir(cur_dir)):
        if not epochfile.startswith('epoch'):
            continue
            
        with open(cur_dir + "/"+epochfile, 'rb') as f:
            d = cPickle.load(f)
            
        epoch = d['epoch']
        epochs.append(epoch)
        wnorms.append(d['data']['weights_norm'])
        means.append(d['data']['gradmean'])
        stds.append(d['data']['gradstd'])

    wnorms, means, stds = map(np.array, [wnorms, means, stds])
    for lndx,layerid in enumerate(PLOT_LAYERS):
        plt.subplot(gs[actndx, lndx])
        plt.plot(epochs, means[:,layerid], 'b', label="Mean")
        plt.plot(epochs, stds[:,layerid], 'orange', label="Std")
        plt.plot(epochs, means[:,layerid]/stds[:,layerid], 'red', label="SNR")
        plt.plot(epochs, wnorms[:,layerid], 'g', label="||W||")

        plt.title('Layer %d'%layerid)
        plt.xlabel('Epoch')
        plt.gca().set_xscale("log", nonposx='clip')
        plt.gca().set_yscale("log", nonposy='clip')
    

plt.legend(loc='lower left', bbox_to_anchor=(1.1, 0.2))
plt.tight_layout()

if DO_SAVE:
    plt.savefig('plots/' + DIR_TEMPLATE % ('snr_'+ARCH), bbox_inches='tight')
# Out:
# /home/laika117/anaconda3/envs/artemy/lib/python2.7/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
